# %%
import pandas as pd

# %%
pd.read_csv('amazon_datas.csv')
# Out:
#      Unnamed: 0                                       Product Name  \
# 0             0  URBAN TRIBE Havana 15.6" inch Laptop Backpack ...
# 1             1  Wesley Milestone 2.0 Casual Waterproof Laptop ...
# 2             2  American Tourister 32 Ltrs Black Casual Backpa...
# 3             3          Skybags Brat Black 46 Cms Casual Backpack
# 4             4  ADISA 15.6 inch Laptop Backpack Office Bag Col...
# ..          ...                                                ...
# 205         205  Farraige® Cartoon Soft Silicone Bag Crossbody ...
# 206         206  LuvLap Baby Breast Milk Storage Bags (Pack of ...
# 207         207  Bennett Casual Laptop Bag school bags for boys...
# 208         208  Wenger 17.5" ScanSmart Laptop Backpack, 30 Lit...
# 209         209  COSMUS Agility Convertible Backpack Messenger ...
#
#                                            Product URL Product Price  Rating  \
# 0    https://www.amazon.in//sspa/click?ie=UTF8&spc=...           998     3.9
# ...
